# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import seaborn as sns; sns.set(style="ticks", color_codes=True)

# %%
features=pd.read_csv('features.csv')

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
stores = pd.read_csv('stores.csv')
sample_submission=pd.read_csv('sampleSubmission.csv')
features=pd.read_csv('features.csv')

# %%
dataset = pd.read_csv("train.csv",sep=',', header=0)
dataset = dataset.merge(stores, how='left')
dataset=dataset.merge(features,how='left')

# %%
testdataset= pd.read_csv("test.csv",sep=',', header=0)
testdataset=testdataset.merge(stores,how='left')
testdataset=testdataset.merge(features,how='left')

# %%
testdataset['Weekly_Sales']=0

# %%
testdataset['Type_A']=pd.get_dummies(testdataset['Type'])['A']
testdataset['Type_B']=pd.get_dummies(testdataset['Type'])['B']
testdataset['Type_C']=pd.get_dummies(testdataset['Type'])['C']
testdataset=testdataset.drop(['Type'],axis=1)

# %%
Nan_percent = dataset.isnull().sum()*100/len(dataset)
Nan_percent
# Out:
# Store           0.0
# Dept            0.0
# Date            0.0
# Weekly_Sales    0.0
# IsHoliday       0.0
# Size            0.0
# Temperature     0.0
# Fuel_Price      0.0
# MarkDown1       0.0
# MarkDown2       0.0
# MarkDown3       0.0
# MarkDown4       0.0
# MarkDown5       0.0
# CPI             0.0
# Unemployment    0.0
# Type_A          0.0
# Type_B          0.0
# Type_C          0.0
# dtype: float64

# %%
Nan_data_test = testdataset.isnull().sum()*100/len(testdataset)
Nan_data_test
# Out:
# Store            0.00000
# Dept             0.00000
# Date             0.00000
# IsHoliday        0.00000
# Size             0.00000
# Temperature      0.00000
# Fuel_Price       0.00000
# MarkDown1        0.00000
# MarkDown2        0.00000
# MarkDown3        0.00000
# MarkDown4        0.00000
# MarkDown5        0.00000
# CPI             33.16589
# Unemployment    33.16589
# Weekly_Sales     0.00000
# Type_A           0.00000
# Type_B           0.00000
# Type_C           0.00000
# dtype: float64

# %%
dataset['Type_A']=pd.get_dummies(dataset['Type'])['A']
dataset['Type_B']=pd.get_dummies(dataset['Type'])['B']
dataset['Type_C']=pd.get_dummies(dataset['Type'])['C']
dataset=dataset.drop(['Type'],axis=1)

# %%
#print(dataset['MarkDown1'].describe())
#print(dataset['MarkDown2'].describe())
#print(dataset['MarkDown3'].describe())
#print(dataset['MarkDown4'].describe())
#print(dataset['MarkDown5'].describe())
print(testdataset['MarkDown1'].describe())
print(testdataset['MarkDown2'].describe())
print(testdataset['MarkDown3'].describe())
print(testdataset['MarkDown4'].describe())
print(testdataset['MarkDown5'].describe())
# Out:
# count    114915.000000
# mean       7689.216439
# std       10698.760716
# min       -2781.450000
# 25%        1966.460000
# 50%        4842.290000
# 75%        9439.140000
# max      103184.980000
# Name: MarkDown1, dtype: float64
# count    86437.000000
# mean      3734.051729
# std       8323.495014
# min        -35.740000
# 25%        180.350000
# 50%        742.590000
# 75%       2735.670000
# max      71074.170000
# Name: MarkDown2, dtype: float64
# count    105235.000000
# mean       2403.088666
# std       13767.939313
# min        -179.260000
# 25%          15.100000
# 50%          78.260000
# 75%         272.580000
# max      149483.310000
# Name: MarkDown3, dtype: float64
# count    102176.000000
# mean       3356.219071
# std        7570.501545
# min           0.220000
# 25%         155.460000
# 50%         840.940000
# 75%        3096.920000
# max       65344.640000
# Name: MarkDown4, dtype: float64
# count    115064.000000
# mean       3922.681189
# ...

# %%
dataset['MarkDown1']=dataset['MarkDown1'].fillna(7246)
dataset['MarkDown2']=dataset['MarkDown2'].fillna(3334)
dataset['MarkDown3']=dataset['MarkDown3'].fillna(1439)
dataset['MarkDown4']=dataset['MarkDown4'].fillna(3383)
dataset['MarkDown5']=dataset['MarkDown5'].fillna(4628)
testdataset['MarkDown1']=testdataset['MarkDown1'].fillna(7689)
testdataset['MarkDown2']=testdataset['MarkDown2'].fillna(3734)
testdataset['MarkDown3']=testdataset['MarkDown3'].fillna(2403)
testdataset['MarkDown4']=testdataset['MarkDown4'].fillna(3356)
testdataset['MarkDown5']=testdataset['MarkDown5'].fillna(3922)

# %%
#dataset[['MarkDown1','MarkDown2','MarkDown3','MarkDown4', 'MarkDown5']] = dataset[['MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5']].fillna(0)

# %%
#testdataset[['MarkDown1','MarkDown2','MarkDown3','MarkDown4', 'MarkDown5']] = testdataset[['MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5']].fillna(0)

# %%
Markdown1_train=dataset[(dataset['MarkDown1']!=0)]
Markdown1_train=Markdown1_train.drop(["MarkDown2","MarkDown3","MarkDown4","MarkDown5"],axis=1)
Markdown1_test=dataset[(dataset['MarkDown1']==0)]
Markdown1_test=Markdown1_test.drop(["MarkDown2","MarkDown3","MarkDown4","MarkDown5"],axis=1)
Markdown2_train=dataset[(dataset['MarkDown2']!=0)]
Markdown2_train=Markdown2_train.drop(["MarkDown1","MarkDown3","MarkDown4","MarkDown5"],axis=1)
Markdown2_test=dataset[(dataset['MarkDown2']==0)]
Markdown2_test=Markdown2_test.drop(["MarkDown1","MarkDown3","MarkDown4","MarkDown5"],axis=1)
Markdown3_train=dataset[(dataset['MarkDown3']!=0)]
Markdown3_train=Markdown3_train.drop(["MarkDown2","MarkDown1","MarkDown4","MarkDown5"],axis=1)
Markdown3_test=dataset[(dataset['MarkDown3']==0)]
Markdown3_test=Markdown3_test.drop(["MarkDown2","MarkDown1","MarkDown4","MarkDown5"],axis=1)
Markdown4_train=dataset[(dataset['MarkDown4']!=0)]
Markdown4_train=Markdown4_train.drop(["MarkDown2","MarkDown3","MarkDown1","MarkDown5"],axis=1)
Markdown4_test=dataset[(dataset['MarkDown4']==0)]
Markdown4_test=Markdown4_test.drop(["MarkDown2","MarkDown3","MarkDown1","MarkDown5"],axis=1)
Markdown5_train=dataset[(dataset['MarkDown5']!=0)]
Markdown5_train=Markdown5_train.drop(["MarkDown2","MarkDown3","MarkDown4","MarkDown1"],axis=1)
Markdown5_test=dataset[(dataset['MarkDown5']==0)]
Markdown5_test=Markdown5_test.drop(["MarkDown2","MarkDown3","MarkDown4","MarkDown1"],axis=1)

# %%
testdataset['CPI']=testdataset['CPI'].fillna(176)# 176 is the mean of all CPI values
testdataset['Unemployment']=testdataset['Unemployment'].fillna(6.868) # 6.86 is the mean of all Unemployment rates.

# %%
dataset['Month']= pd.to_datetime(dataset['Date']).dt.month

# %%
testdataset['Month']=pd.to_datetime(testdataset['Date']).dt.month

# %%
X=dataset.drop(["Date","Weekly_Sales"],axis=1)
y=dataset['Weekly_Sales']
from sklearn.linear_model import LinearRegression
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)
lm=LinearRegression()
lm.fit(X_train,y_train)
predictions=lm.predict(X_test)

# %%
X_train
# Out:
#         Store  Dept  IsHoliday    Size  Temperature  Fuel_Price  MarkDown1  \
# 129684     14    12       True  200898        70.87       2.699    7246.00
# 136020     14    79      False  200898        41.18       3.513    4605.80
# 322819     34    17      False  158114        65.41       3.620    2716.10
# 333929     35    25      False  103681        70.31       2.755    7246.00
# 162560     17    38      False   93188        39.94       3.755    5593.69
# 33892       4    32      False  205863        40.31       3.290    1346.06
# 277335     29     2       True   93638        36.28       3.402    2168.59
# 417975     45    52      False  118221        78.47       3.760    7246.00
# 54629       6    45      False  202505        53.74       2.732    7246.00
# 175674     18    83      False  120653        27.40       3.139    7246.00
# 284228     29    72      False   93638        39.42       3.065    7246.00
# ...

# %%
predictions=np.where(predictions<=0,0, predictions)

# %%
y_m1test=testdataset.drop(["Date","Weekly_Sales"],axis=1)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, rf_predictions)
# Out:
# 1712.6661766017507

# %%
r2_score(y_test, knn_predictions)
# Out:
# 0.27233543183343956

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import RFE
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import KFold

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
train_scaled=scaler.fit_transform(X_train)
test_scaled=scaler.transform(X_test)
# Out:
# C:\Users\Sinan\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype bool, uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Sinan\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype bool, uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\Sinan\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype bool, uint8, int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor()
model.fit(train_scaled,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='uniform')

# %%
knn_predictions=model.predict(test_scaled)

# %%
modelrf=RandomForestRegressor()
modelrf.fit(train_scaled,y_train)
# Out:
# C:\Users\Sinan\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf_predictions=modelrf.predict(test_scaled)

# %%
scaled_data=scaler.fit_transform(y_m1test)
# Out:
# C:\Users\Sinan\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype bool, uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Sinan\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype bool, uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
results=modelrf.predict(scaled_data)

# %%
sample_submission['Weekly_Sales']=results

# %%
sample_submission
# Out:
#                       Id  Weekly_Sales
# 0         1_1_2012-11-02     19457.773
# 1         1_1_2012-11-09     22007.085
# 2         1_1_2012-11-16     19891.613
# 3         1_1_2012-11-23     21420.876
# 4         1_1_2012-11-30     24901.331
# 5         1_1_2012-12-07     29954.078
# 6         1_1_2012-12-14     39731.857
# 7         1_1_2012-12-21     38398.561
# 8         1_1_2012-12-28     23565.930
# 9         1_1_2013-01-04     44190.434
# 10        1_1_2013-01-11     38856.317
# 11        1_1_2013-01-18     23399.277
# 12        1_1_2013-01-25     28107.365
# 13        1_1_2013-02-01     23933.175
# 14        1_1_2013-02-08     32352.617
# 15        1_1_2013-02-15     22218.840
# 16        1_1_2013-02-22     20886.542
# 17        1_1_2013-03-01     29315.246
# 18        1_1_2013-03-08     18098.786
# 19        1_1_2013-03-15     16302.240
# 20        1_1_2013-03-22     68456.222
# 21        1_1_2013-03-29     28107.920
# 22        1_1_2013-04-05     19531.499
# ...

# %%
sample_submission.to_csv('../walmart_submission.csv',index=False)

# %%
y_m1test
# Out:
#         Store  Dept  IsHoliday    Size  Temperature  Fuel_Price  MarkDown1  \
# 0           1     1      False  151315        55.32       3.386    6766.44
# 1           1     1      False  151315        61.24       3.314   11421.32
# 2           1     1      False  151315        52.92       3.252    9696.28
# 3           1     1       True  151315        56.23       3.211     883.59
# 4           1     1      False  151315        52.34       3.207    2460.03
# 5           1     1      False  151315        64.12       3.198    6343.16
# 6           1     1      False  151315        48.89       3.168    3504.83
# 7           1     1      False  151315        56.02       3.098    8231.71
# 8           1     1       True  151315        44.79       3.108   12659.55
# 9           1     1      False  151315        41.73       3.161    1214.08
# 10          1     1      False  151315        50.32       3.243    6520.24
# ...

# %%
y_predict = model.predict(X_test)

# %%
dataset.iloc[:,2]

# %%
pd.DataFrame(predictions,y_test)
# Out:
#                          0
# Weekly_Sales
# 9214.04       28275.688033
# 2681.04       15846.663043
# 14683.34      19674.516316
# 45.00          3349.029974
# 120557.54     22588.397953
# 5658.50       18535.668606
# 5221.03        8824.540355
# 5421.14       14270.341895
# 3816.56       10570.573131
# 49.26          6920.283339
# 41008.01      17553.093025
# 19798.48      11179.792109
# 28.92         16902.540979
# 2705.79       16326.804933
# 2363.66       10391.471354
# 113.57        11681.734743
# 50197.97      24739.765369
# 12396.98      15709.363398
# 1933.16       16917.091138
# 26049.53      18070.366317
# 30.00         23558.739205
# 32.48         18364.575189
# 59.08         20418.278973
# 2.00           5985.653620
# 3852.40        9178.035099
# 76.34          7177.097840
# 7212.24       20330.651307
# 43265.29      28829.524233
# 4826.13        4240.432493
# 175.13        12843.457677
# ...                    ...
# 6964.62        6086.722686
# ...

# %%
predictions_MD1=lm.predict(y_m1test)

# %%
X=Markdown2_train.drop(["Date","Weekly_Sales","MarkDown2"],axis=1)
y=Markdown2_train['MarkDown2']
from sklearn.linear_model import LinearRegression
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)
lm2=LinearRegression()
lm2.fit(X_train,y_train)
predictions_MD2=lm2.predict(y_m1test)

# %%
X=Markdown3_train.drop(["Date","Weekly_Sales","MarkDown3"],axis=1)
y=Markdown3_train['MarkDown3']
from sklearn.linear_model import LinearRegression
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)
lm3=LinearRegression()
lm3.fit(X_train,y_train)
predictions_MD3=lm3.predict(y_m1test)

# %%
X=Markdown4_train.drop(["Date","Weekly_Sales","MarkDown4"],axis=1)
y=Markdown4_train['MarkDown4']
from sklearn.linear_model import LinearRegression
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)
lm4=LinearRegression()
lm4.fit(X_train,y_train)
predictions_MD4=lm4.predict(y_m1test)

# %%
X=Markdown5_train.drop(["Date","Weekly_Sales","MarkDown5"],axis=1)
y=Markdown5_train['MarkDown5']
from sklearn.linear_model import LinearRegression
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)
lm5=LinearRegression()
lm5.fit(X_train,y_train)
predictions_MD5=lm5.predict(y_m1test)

# %%
testdataset['cl3'].describe()
# Out:
# count    115064.000000
# mean       1419.516505
# std        4072.211228
# min       -2606.096946
# 25%         -69.741933
# 50%         401.617292
# 75%         901.022185
# max       17117.912880
# Name: cl3, dtype: float64

# %%
testdataset['MarkDown3'].describe()
# Out:
# count    115064.000000
# mean       2197.811964
# std       13183.888087
# min        -179.260000
# 25%           7.770000
# 50%          60.000000
# 75%         244.200000
# max      149483.310000
# Name: MarkDown3, dtype: float64

# %%
testdataset
# Out:
#         Store  Dept        Date  IsHoliday    Size  Temperature  Fuel_Price  \
# 0           1     1  2012-11-02      False  151315        55.32       3.386
# 1           1     1  2012-11-09      False  151315        61.24       3.314
# 2           1     1  2012-11-16      False  151315        52.92       3.252
# 3           1     1  2012-11-23       True  151315        56.23       3.211
# 4           1     1  2012-11-30      False  151315        52.34       3.207
# 5           1     1  2012-12-07      False  151315        64.12       3.198
# 6           1     1  2012-12-14      False  151315        48.89       3.168
# 7           1     1  2012-12-21      False  151315        56.02       3.098
# 8           1     1  2012-12-28       True  151315        44.79       3.108
# 9           1     1  2013-01-04      False  151315        41.73       3.161
# 10          1     1  2013-01-11      False  151315        50.32       3.243
# ...

# %%
testdataset['MarkDown2'][4]==0
# Out:
# True

# %%
for i in range(0,115064):
    if testdataset['MarkDown1'][i]==0.0:
        testdataset['MarkDown1'][i]==predictions_MD1[i]
    if testdataset['MarkDown2'][i]==0.0:
        testdataset['MarkDown2'][i]==predictions_MD2[i]
    if testdataset['MarkDown3'][i]==0.0:
        testdataset['MarkDown3'][i]==predictions_MD3[i]
    if testdataset['MarkDown4'][i]==0.0:
        testdataset['MarkDown4'][i]==predictions_MD4[i]
    if testdataset['MarkDown5'][i]==0.0:
        testdataset['MarkDown5'][i]==predictions_MD5[i]

# %%
TT=testdataset.drop(["MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5"],axis=1)

# %%
TT
# Out:
#         Store  Dept        Date  IsHoliday    Size  Temperature  Fuel_Price  \
# 0           1     1  2012-11-02      False  151315        55.32       3.386
# 1           1     1  2012-11-09      False  151315        61.24       3.314
# 2           1     1  2012-11-16      False  151315        52.92       3.252
# 3           1     1  2012-11-23       True  151315        56.23       3.211
# 4           1     1  2012-11-30      False  151315        52.34       3.207
# 5           1     1  2012-12-07      False  151315        64.12       3.198
# 6           1     1  2012-12-14      False  151315        48.89       3.168
# 7           1     1  2012-12-21      False  151315        56.02       3.098
# 8           1     1  2012-12-28       True  151315        44.79       3.108
# 9           1     1  2013-01-04      False  151315        41.73       3.161
# 10          1     1  2013-01-11      False  151315        50.32       3.243
# ...

# %%
for i in range(0,115064):
    if (testdataset['MarkDown2'][i]==0.0):
        testdataset['MarkDown2'][i]=testdataset['cl2'][i]

# %%
testdataset['cl1']=predictions_MD1
testdataset['cl2']=predictions_MD2
testdataset['cl3']=predictions_MD3
testdataset['cl4']=predictions_MD4
testdataset['cl5']=predictions_MD5

# %%
testdataset
# Out:
#         Store  Dept        Date  IsHoliday    Size  Temperature  Fuel_Price  \
# 0           1     1  2012-11-02      False  151315        55.32       3.386
# 1           1     1  2012-11-09      False  151315        61.24       3.314
# 2           1     1  2012-11-16      False  151315        52.92       3.252
# 3           1     1  2012-11-23       True  151315        56.23       3.211
# 4           1     1  2012-11-30      False  151315        52.34       3.207
# 5           1     1  2012-12-07      False  151315        64.12       3.198
# 6           1     1  2012-12-14      False  151315        48.89       3.168
# 7           1     1  2012-12-21      False  151315        56.02       3.098
# 8           1     1  2012-12-28       True  151315        44.79       3.108
# 9           1     1  2013-01-04      False  151315        41.73       3.161
# 10          1     1  2013-01-11      False  151315        50.32       3.243
# ...

# %%
testdataset['MarkDown1'].
